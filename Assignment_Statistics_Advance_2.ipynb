# %% [markdown]
# 1. What is hypothesis testing in statistics?
#
# Ans. Hypothesis testing is a statistical method used to decide whether there's enough evidence in a sample to support a specific claim about a population.
#
# Null Hypothesis (H₀): No effect or difference (status quo).
#
# Alternative Hypothesis (H₁): What you're testing for.
#
# Significance Level (α): The threshold for rejecting H₀ (commonly 0.05).
#
# P-value: Probability of observing the result if H₀ is true.
#
# If p ≤ α, reject H₀.
#
# If p > α, do not reject H₀.
#
# It helps make data-driven decisions or test claims.

# %% [markdown]
# 2.  What is the null hypothesis, and how does it differ from the alternative hypothesis?
#
# Ans. Null hypothesis (H₀): Assumes no effect or no difference.
#
# Alternative hypothesis (H₁ or Ha): Assumes there is an effect or difference.
#
# Difference: H₀ is the default; H₁ is what you're trying to prove.

# %% [markdown]
# 3. What is the significance level in hypothesis testing, and why is it important?
#
# Ans. Significance level (α): The probability of rejecting the null hypothesis when it is true (Type I error).
#
# Common value: 0.05
#
# Importance: Sets the threshold for deciding if results are statistically significant.

# %% [markdown]
# 4. What does a P-value represent in hypothesis testing?
#
# Ans. P-value: The probability of getting the observed results (or more extreme) if the null hypothesis is true.
#
# Low p-value (≤ α): Strong evidence against H₀ → reject H₀.
#
# High p-value (> α): Weak evidence → fail to reject H₀.

# %% [markdown]
# 5. How do you interpret the P-value in hypothesis testing?
#
# Ans. P ≤ α: Reject the null hypothesis (evidence supports H₁).
#
# P > α: Fail to reject the null hypothesis (not enough evidence).
# It tells how likely the result is if H₀ is true.

# %% [markdown]
# 6. What are Type 1 and Type 2 errors in hypothesis testing?
#
# Ans. Type 1 Error (α): Rejecting H₀ when it is true (false positive).
#
# Type 2 Error (β): Failing to reject H₀ when H₁ is true (false negative).

# %% [markdown]
# 7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
#
# Ans. One-tailed test: Tests for effect in one direction (e.g., greater than).
#
# Two-tailed test: Tests for effect in both directions (e.g., not equal to).
# Use depends on the hypothesis.

# %% [markdown]
# 8. What is the Z-test, and when is it used in hypothesis testing?
#
# Ans. Z-test: A statistical test used when the population variance is known and the sample size is large (n ≥ 30).
#
# Used for: Testing means or proportions with normal distribution.

# %% [markdown]
# 9. How do you calculate the Z-score, and what does it represent in hypothesis testing?
#
# Ans. Z-score formula:
#
# 𝑍
# =
# Sample value
# −
# Population mean /
# ( Standard deviation
# /
# 𝑛 )
#
# Represents: How many standard deviations the sample value is from the population mean.
# Used to determine how unusual the sample result is under H₀.

# %% [markdown]
# 10.  What is the T-distribution, and when should it be used instead of the normal distribution?
#
# Ans. T-distribution: A probability distribution similar to normal but with heavier tails.
#
# Use it when:
#
# Sample size is small (n < 30)
#
# Population standard deviation is unknown.

# %% [markdown]
# 11. What is the difference between a Z-test and a T-test?
#
# Ans. Z-test: Uses known population standard deviation, large samples (n ≥ 30).
#
# T-test: Uses sample standard deviation, small samples (n < 30), or unknown population std.

# %% [markdown]
# 12. What is the T-test, and how is it used in hypothesis testing?
#
# Ans. T-test: A test that compares sample mean to a population mean when the population standard deviation is unknown.
#
# Used for: Small samples to check if the mean differs from a value or between groups.

# %% [markdown]
# 13. What is the relationship between Z-test and T-test in hypothesis testing?
#
# Ans. The T-test approaches the Z-test as sample size grows large because the sample standard deviation better estimates the population standard deviation.
#
# Use T-test for small samples/unknown std dev.
#
# Use Z-test for large samples/known std dev.

# %% [markdown]
# 14.  What is a confidence interval, and how is it used to interpret statistical results?
#
# Ans. Confidence interval: A range of values likely containing the true population parameter with a certain confidence level (e.g., 95%).
#
# Use: To estimate parameters and assess precision; if it excludes a value (like zero), results may be significant.

# %% [markdown]
# 15. What is the margin of error, and how does it affect the confidence interval?
#
# Ans. Margin of error: The maximum expected difference between the sample estimate and the true population value.
#
# Effect: Larger margin → wider confidence interval; smaller margin → narrower interval, meaning more precise estimates.

# %% [markdown]
# 16.  How is Bayes' Theorem used in statistics, and what is its significance?
#
# Ans. Bayes' Theorem: Updates the probability of a hypothesis based on new evidence.
#
# Significance: Combines prior knowledge with data to improve decision-making and predictions.

# %% [markdown]
# 17. What is the Chi-square distribution, and when is it used?
#
# Ans. Chi-square distribution: A probability distribution used for testing relationships between categorical variables.
#
# Used in: Chi-square tests for goodness-of-fit and independence in contingency tables.

# %% [markdown]
# 18. What is the Chi-square goodness of fit test, and how is it applied?
#
# Ans. Chi-square goodness of fit test: Checks if observed data matches expected frequencies for a category.
#
# Applied by: Comparing observed counts to expected counts, then calculating a Chi-square statistic to see if differences are due to chance.

# %% [markdown]
# 19. What is the F-distribution, and when is it used in hypothesis testing?
#
# Ans. F-distribution: A probability distribution used to compare variances between groups.
#
# Used in: ANOVA and tests comparing two variances.

# %% [markdown]
# 20. What is an ANOVA test, and what are its assumptions?
#
# Ans. ANOVA (Analysis of Variance): Tests if means of three or more groups are equal.
#
# Assumptions:
#
# Independent samples
#
# Normally distributed groups
#
# Equal variances (homogeneity of variance)

# %% [markdown]
# 21. What are the different types of ANOVA tests?
#
# Ans. One-way ANOVA: Tests one factor with multiple groups.
#
# Two-way ANOVA: Tests two factors and their interaction.
#
# Repeated Measures ANOVA: Tests the same subjects under different conditions/time points.

# %% [markdown]
# 22. What is the F-test, and how does it relate to hypothesis testing?
#
# Ans. F-test: Compares variances to see if groups differ significantly.
#
# Relation: Used in ANOVA and regression to test if model or group differences are significant.

# %% [markdown]
# **Practical Part - 1**

# %% [markdown]
# 1. Write a Python program to generate a random variable and display its value?

# %%
import random

# Generate a random float between 0 and 1
random_variable = random.random()

# Display the value
print("Random Variable:", random_variable)
# Out:
# Random Variable: 0.7128308636250865

# %% [markdown]
# 2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF)?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Define the range for the discrete uniform distribution
low = 1
high = 7  # values from 1 to 6 (like a die)

# Create the discrete uniform distribution
dist = randint(low, high)

# PMF values
x = np.arange(low, high)
pmf = dist.pmf(x)

# Plot the PMF
plt.stem(x, pmf)
plt.title("Discrete Uniform Distribution PMF")
plt.xlabel("Value")        # ✅ Correct
plt.ylabel("Probability")  # ✅ Correct
plt.grid(True)
plt.show()

# %% [markdown]
# 3.  Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution?

# %%
def bernoulli_pdf(x, p):
    """
    Calculate the PDF of a Bernoulli distribution.

    Parameters:
    x (int): Outcome (0 or 1)
    p (float): Probability of success (0 ≤ p ≤ 1)

    Returns:
    float: Probability of observing x
    """
    if x not in [0, 1]:
        raise ValueError("x must be 0 or 1 for a Bernoulli distribution.")
    if not (0 <= p <= 1):
        raise ValueError("p must be between 0 and 1.")

    return p**x * (1 - p)**(1 - x)

# %% [markdown]
# 4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
n = 10       # number of trials
p = 0.5      # probability of success
size = 1000  # number of simulations

# Simulate binomial distribution
data = np.random.binomial(n, p, size)

# Plot histogram
plt.hist(data, bins=np.arange(0, n+2)-0.5, density=True, edgecolor='black')
plt.title("Binomial Distribution Histogram (n=10, p=0.5)")
plt.xlabel("Number of Successes")
plt.ylabel("Probability")
plt.grid(True)
plt.show()

# %% [markdown]
# 5. Create a Poisson distribution and visualize it using Python?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Parameters
lambda_val = 4  # average rate (λ)
x = np.arange(0, 15)  # range of values

# PMF of the Poisson distribution
pmf = poisson.pmf(x, mu=lambda_val)

# Plot the Poisson PMF
plt.stem(x, pmf)
plt.title("Poisson Distribution (λ = 4)")
plt.xlabel("Number of Events")
plt.ylabel("Probability")
plt.grid(True)
plt.show()

# %% [markdown]
# 6. Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Parameters for discrete uniform distribution (like a die)
low = 1
high = 7  # Values: 1 to 6

# Create the distribution
dist = randint(low, high)

# Define values
x = np.arange(low, high)
cdf = dist.cdf(x)

# Plot the CDF
plt.step(x, cdf, where='post')
plt.title("CDF of Discrete Uniform Distribution (1 to 6)")
plt.xlabel("Value")
plt.ylabel("Cumulative Probability")
plt.grid(True)
plt.show()

# %% [markdown]
# 7.  Generate a continuous uniform distribution using NumPy and visualize it.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
low = 0
high = 10
size = 1000  # Number of samples

# Generate continuous uniform data
data = np.random.uniform(low, high, size)

# Plot histogram
plt.hist(data, bins=30, density=True, edgecolor='black')
plt.title("Continuous Uniform Distribution")
plt.xlabel("Value")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %% [markdown]
# 8.  Simulate data from a normal distribution and plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
mean = 0
std_dev = 1
size = 1000

# Generate normal distribution data
data = np.random.normal(mean, std_dev, size)

# Plot histogram
plt.hist(data, bins=30, density=True, edgecolor='black')
plt.title("Normal Distribution Histogram (mean=0, std=1)")
plt.xlabel("Value")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %% [markdown]
# 9.  Write a Python function to calculate Z-scores from a dataset and plot them.

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_and_plot_zscores(data):
    data = np.array(data)
    mean = np.mean(data)
    std = np.std(data)
    z_scores = (data - mean) / std

    plt.stem(z_scores)
    plt.title("Z-scores of the Dataset")
    plt.xlabel("Index")
    plt.ylabel("Z-score")
    plt.grid(True)
    plt.show()

    return z_scores

# Example usage:
sample_data = [10, 12, 9, 15, 10, 8, 13, 11]
calculate_and_plot_zscores(sample_data)
# Out:
# array([-0.47140452,  0.47140452, -0.94280904,  1.88561808, -0.47140452,
#        -1.41421356,  0.94280904,  0.        ])

# %% [markdown]
# 10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
sample_size = 30     # size of each sample
num_samples = 1000   # number of samples

# Generate samples from an exponential distribution (non-normal)
data = np.random.exponential(scale=1, size=sample_size * num_samples)

# Reshape data into samples
samples = data.reshape(num_samples, sample_size)

# Calculate sample means
sample_means = samples.mean(axis=1)

# Plot histogram of sample means
plt.hist(sample_means, bins=30, density=True, edgecolor='black')
plt.title("CLT: Distribution of Sample Means (Exponential Data)")
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %% [markdown]
# 11. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
population_mean = 5
population_std = 2
sample_size = 30
num_samples = 1000

# Generate multiple samples from the normal distribution
samples = np.random.normal(population_mean, population_std, (num_samples, sample_size))

# Calculate sample means
sample_means = samples.mean(axis=1)

# Plot histogram of sample means
plt.hist(sample_means, bins=30, density=True, edgecolor='black')
plt.title("CLT Verification: Distribution of Sample Means")
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %% [markdown]
# 12. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal():
    x = np.linspace(-4, 4, 1000)  # range for plotting
    y = norm.pdf(x, loc=0, scale=1)  # standard normal PDF

    plt.plot(x, y)
    plt.title("Standard Normal Distribution (mean=0, std=1)")
    plt.xlabel("x")
    plt.ylabel("Probability Density")
    plt.grid(True)
    plt.show()

# Call the function
plot_standard_normal()

# %% [markdown]
# 13.  Generate random variables and calculate their corresponding probabilities using the binomial distribution.

# %%
import numpy as np
from scipy.stats import binom

# Parameters
n = 10    # number of trials
p = 0.5   # probability of success

# Generate possible outcomes (0 to n)
x = np.arange(n + 1)

# Calculate probabilities (PMF)
probabilities = binom.pmf(x, n, p)

# Display outcomes with probabilities
for outcome, prob in zip(x, probabilities):
    print(f"P(X = {outcome}) = {prob:.4f}")
# Out:
# P(X = 0) = 0.0010
# P(X = 1) = 0.0098
# P(X = 2) = 0.0439
# P(X = 3) = 0.1172
# P(X = 4) = 0.2051
# P(X = 5) = 0.2461
# P(X = 6) = 0.2051
# P(X = 7) = 0.1172
# P(X = 8) = 0.0439
# P(X = 9) = 0.0098
# P(X = 10) = 0.0010

# %% [markdown]
# 14. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_z_score(data_point, data):
    mean = np.mean(data)
    std = np.std(data)
    z = (data_point - mean) / std
    return z

# Sample data
data = [10, 12, 9, 15, 10, 8, 13, 11]

# Data point to calculate Z-score for
data_point = 14

# Calculate Z-score
z_score = calculate_z_score(data_point, data)
print(f"Z-score of {data_point}: {z_score:.2f}")

# Plot standard normal distribution
x = np.linspace(-4, 4, 1000)
y = norm.pdf(x, 0, 1)
plt.plot(x, y, label='Standard Normal PDF')

# Mark Z-score on the plot
plt.axvline(z_score, color='r', linestyle='--', label=f'Z-score = {z_score:.2f}')
plt.title('Standard Normal Distribution with Z-score')
plt.xlabel('Z-score')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Z-score of 14: 1.41

# %% [markdown]
# 15. Implement hypothesis testing using Z-statistics for a sample dataset.

# %%
import numpy as np
from scipy.stats import norm

# Sample data
sample = [12, 15, 14, 10, 13, 12, 11, 14, 13, 12]
sample_mean = np.mean(sample)
sample_size = len(sample)

# Known population parameters (for Z-test)
population_mean = 10
population_std = 2

# Significance level
alpha = 0.05

# Calculate Z-statistic
z_stat = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

# Calculate p-value (two-tailed test)
p_value = 2 * (1 - norm.cdf(abs(z_stat)))

# Output results
print(f"Sample mean: {sample_mean:.2f}")
print(f"Z-statistic: {z_stat:.2f}")
print(f"P-value: {p_value:.4f}")

if p_value < alpha:
    print("Reject the null hypothesis.")
else:
    print("Fail to reject the null hypothesis.")
# Out:
# Sample mean: 12.60
# Z-statistic: 4.11
# P-value: 0.0000
# Reject the null hypothesis.

# %% [markdown]
# 16.  Create a confidence interval for a dataset using Python and interpret the result.

# %%
import numpy as np
import scipy.stats as stats

# Sample data
data = [12, 15, 14, 10, 13, 12, 11, 14, 13, 12]

# Parameters
confidence_level = 0.95
n = len(data)
mean = np.mean(data)
std_err = stats.sem(data)  # standard error of the mean

# Calculate margin of error
h = std_err * stats.t.ppf((1 + confidence_level) / 2, n - 1)

# Confidence interval
lower_bound = mean - h
upper_bound = mean + h

print(f"Sample Mean = {mean:.2f}")
print(f"{confidence_level*100:.0f}% Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")
# Out:
# Sample Mean = 12.60
# 95% Confidence Interval: (11.52, 13.68)

# %% [markdown]
# 17.  Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.

# %%
import numpy as np
import scipy.stats as stats

# Generate normal distribution data
np.random.seed(0)  # for reproducibility
data = np.random.normal(loc=50, scale=5, size=100)  # mean=50, std=5, n=100

# Calculate statistics
confidence_level = 0.95
n = len(data)
mean = np.mean(data)
std_err = stats.sem(data)  # standard error

# Calculate margin of error
h = std_err * stats.t.ppf((1 + confidence_level) / 2, n - 1)

# Confidence interval
lower_bound = mean - h
upper_bound = mean + h

print(f"Sample Mean = {mean:.2f}")
print(f"{confidence_level*100:.0f}% Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")

# Interpretation
print(f"\nInterpretation: We are {confidence_level*100:.0f}% confident that the true population mean lies between {lower_bound:.2f} and {upper_bound:.2f}.")
# Out:
# Sample Mean = 50.30
# 95% Confidence Interval: (49.29, 51.30)
#
# Interpretation: We are 95% confident that the true population mean lies between 49.29 and 51.30.

# %% [markdown]
# 18. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters
mean = 0
std_dev = 1

# Generate x values
x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)

# Calculate PDF values
pdf = norm.pdf(x, mean, std_dev)

# Plot the PDF
plt.plot(x, pdf)
plt.title("Normal Distribution PDF (mean=0, std=1)")
plt.xlabel("x")
plt.ylabel("Probability Density")
plt.grid(True)
plt.show()

# %% [markdown]
# 19. Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters
mean = 0
std_dev = 1

# Generate x values
x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)

# Calculate PDF values
pdf = norm.pdf(x, mean, std_dev)

# Plot the PDF
plt.plot(x, pdf)
plt.title("Normal Distribution PDF (mean=0, std=1)")
plt.xlabel("x")
plt.ylabel("Probability Density")
plt.grid(True)
plt.show()

# %% [markdown]
# 20.  Simulate a random variable using a continuous uniform distribution and calculate its expected value.

# %%
import numpy as np

# Parameters
low = 0
high = 10
size = 10000  # number of samples

# Generate random samples
samples = np.random.uniform(low, high, size)

# Calculate expected value (mean)
expected_value = np.mean(samples)

print(f"Simulated Expected Value: {expected_value:.4f}")

# Theoretical expected value for uniform(a, b) is (a + b) / 2
theoretical_value = (low + high) / 2
print(f"Theoretical Expected Value: {theoretical_value}")
# Out:
# Simulated Expected Value: 4.9608
# Theoretical Expected Value: 5.0

# %% [markdown]
# 21.  Write a Python program to compare the standard deviations of two datasets and visualize the difference.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample datasets
data1 = [10, 12, 9, 15, 10, 8, 13, 11]
data2 = [7, 14, 6, 18, 9, 7, 20, 13]

# Calculate standard deviations
std1 = np.std(data1, ddof=1)  # sample std deviation
std2 = np.std(data2, ddof=1)

print(f"Standard Deviation of Dataset 1: {std1:.2f}")
print(f"Standard Deviation of Dataset 2: {std2:.2f}")

# Plot comparison
labels = ['Dataset 1', 'Dataset 2']
std_devs = [std1, std2]

plt.bar(labels, std_devs, color=['blue', 'orange'])
plt.ylabel('Standard Deviation')
plt.title('Comparison of Standard Deviations')
plt.grid(axis='y')
plt.show()
# Out:
# Standard Deviation of Dataset 1: 2.27
# Standard Deviation of Dataset 2: 5.34

# %% [markdown]
# 22. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.

# %%
import numpy as np

# Generate data from normal distribution
np.random.seed(0)
data = np.random.normal(loc=50, scale=10, size=100)

# Calculate range
data_range = np.max(data) - np.min(data)

# Calculate IQR
q75, q25 = np.percentile(data, [75, 25])
iqr = q75 - q25

print(f"Range: {data_range:.2f}")
print(f"IQR: {iqr:.2f}")
# Out:
# Range: 48.23
# IQR: 13.81

# %% [markdown]
# 23.  Implement Z-score normalization on a dataset and visualize its transformation.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample dataset
data = [10, 12, 9, 15, 10, 8, 13, 11, 14, 7]

# Convert to numpy array
data = np.array(data)

# Calculate mean and std dev
mean = np.mean(data)
std = np.std(data)

# Z-score normalization
z_normalized = (data - mean) / std

# Plot before and after
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

axs[0].hist(data, bins=5, edgecolor='black')
axs[0].set_title('Original Data')
axs[0].set_xlabel('Value')
axs[0].set_ylabel('Frequency')

axs[1].hist(z_normalized, bins=5, edgecolor='black', color='orange')
axs[1].set_title('Z-score Normalized Data')
axs[1].set_xlabel('Z-score')
axs[1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# 24. Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.

# %%
import numpy as np
from scipy.stats import skew, kurtosis

def calc_skewness_kurtosis(data):
    s = skew(data)
    k = kurtosis(data)  # excess kurtosis by default
    return s, k

# Generate normal distribution data
np.random.seed(0)
data = np.random.normal(loc=0, scale=1, size=1000)

# Calculate skewness and kurtosis
skewness, kurt = calc_skewness_kurtosis(data)

print(f"Skewness: {skewness:.4f}")
print(f"Kurtosis (excess): {kurt:.4f}")
# Out:
# Skewness: 0.0339
# Kurtosis (excess): -0.0468

# %% [markdown]
# **Practical Part - 2**

# %% [markdown]
# 1. Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results.

# %%
import numpy as np
from scipy.stats import norm

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    n = len(sample)
    sample_mean = np.mean(sample)

    # Calculate Z-statistic
    z_stat = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))

    # Two-tailed p-value
    p_value = 2 * (1 - norm.cdf(abs(z_stat)))

    print(f"Sample mean = {sample_mean:.2f}")
    print(f"Z-statistic = {z_stat:.2f}")
    print(f"P-value = {p_value:.4f}")

    if p_value < alpha:
        print("Reject the null hypothesis: sample mean is significantly different from population mean.")
    else:
        print("Fail to reject the null hypothesis: no significant difference between sample and population mean.")

# Example usage
sample_data = [12, 15, 14, 10, 13, 12, 11, 14, 13, 12]
population_mean = 10
population_std = 2  # known population std dev

z_test(sample_data, population_mean, population_std)
# Out:
# Sample mean = 12.60
# Z-statistic = 4.11
# P-value = 0.0000
# Reject the null hypothesis: sample mean is significantly different from population mean.

# %% [markdown]
# 2. Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python.

# %%
import numpy as np
from scipy.stats import norm

# Simulate random data (e.g., sample from normal distribution)
np.random.seed(42)
sample_size = 50
population_mean = 100
population_std = 15  # known population std dev

# Generate sample data with a true mean slightly different than population mean
sample = np.random.normal(loc=105, scale=population_std, size=sample_size)

# Calculate sample mean
sample_mean = np.mean(sample)

# Calculate Z-statistic
z_stat = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

# Calculate two-tailed p-value
p_value = 2 * (1 - norm.cdf(abs(z_stat)))

print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-statistic: {z_stat:.2f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: significant difference detected.")
else:
    print("Fail to reject the null hypothesis: no significant difference detected.")
# Out:
# Sample Mean: 101.62
# Z-statistic: 0.76
# P-value: 0.4457
# Fail to reject the null hypothesis: no significant difference detected.

# %% [markdown]
# 3.  Implement a one-sample Z-test using Python to compare the sample mean with the population mean.

# %%
import numpy as np
from scipy.stats import norm

def one_sample_z_test(sample, pop_mean, pop_std, alpha=0.05):
    n = len(sample)
    sample_mean = np.mean(sample)
    z_stat = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))
    p_value = 2 * (1 - norm.cdf(abs(z_stat)))  # two-tailed p-value

    print(f"Sample Mean: {sample_mean:.2f}")
    print(f"Z-statistic: {z_stat:.2f}")
    print(f"P-value: {p_value:.4f}")

    if p_value < alpha:
        print("Reject the null hypothesis: sample mean is significantly different.")
    else:
        print("Fail to reject the null hypothesis: no significant difference.")

# Example usage
sample_data = [11, 13, 12, 10, 14, 12, 11, 13, 12, 12]
population_mean = 10
population_std = 2

one_sample_z_test(sample_data, population_mean, population_std)
# Out:
# Sample Mean: 12.00
# Z-statistic: 3.16
# P-value: 0.0016
# Reject the null hypothesis: sample mean is significantly different.

# %% [markdown]
# 4.  Perform a two-tailed Z-test using Python and visualize the decision region on a plot.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def two_tailed_z_test(sample, pop_mean, pop_std, alpha=0.05):
    n = len(sample)
    sample_mean = np.mean(sample)
    z_stat = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))

    # Two-tailed p-value
    p_value = 2 * (1 - norm.cdf(abs(z_stat)))

    print(f"Sample Mean = {sample_mean:.2f}")
    print(f"Z-statistic = {z_stat:.2f}")
    print(f"P-value = {p_value:.4f}")

    # Critical z-values for two-tailed test
    z_crit = norm.ppf(1 - alpha/2)
    print(f"Critical z-values: ±{z_crit:.2f}")

    # Decision
    if abs(z_stat) > z_crit:
        print("Reject the null hypothesis.")
    else:
        print("Fail to reject the null hypothesis.")

    # Plotting
    x = np.linspace(-4, 4, 1000)
    y = norm.pdf(x)

    plt.plot(x, y, label='Standard Normal PDF')

    # Shade rejection regions
    plt.fill_between(x, 0, y, where=(x <= -z_crit), color='red', alpha=0.3, label='Rejection Region')
    plt.fill_between(x, 0, y, where=(x >= z_crit), color='red', alpha=0.3)

    # Mark z-statistic
    plt.axvline(z_stat, color='blue', linestyle='--', label=f'Z-statistic = {z_stat:.2f}')

    plt.title('Two-tailed Z-test Decision Regions')
    plt.xlabel('Z-value')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True)
    plt.show()

# Example data
sample_data = [11, 13, 12, 10, 14, 12, 11, 13, 12, 12]
population_mean = 10
population_std = 2

two_tailed_z_test(sample_data, population_mean, population_std)
# Out:
# Sample Mean = 12.00
# Z-statistic = 3.16
# P-value = 0.0016
# Critical z-values: ±1.96
# Reject the null hypothesis.

# %% [markdown]
# 5.  Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_type1_type2_errors(pop_mean, pop_std, sample_size, alpha, true_mean):
    # Critical z-value for alpha (two-tailed)
    z_crit = norm.ppf(1 - alpha/2)

    # Standard error
    se = pop_std / np.sqrt(sample_size)

    # Critical values in sample mean scale
    lower_crit = pop_mean - z_crit * se
    upper_crit = pop_mean + z_crit * se

    # Plot x range covering both distributions
    x = np.linspace(pop_mean - 4*se, true_mean + 4*se, 1000)

    # Null distribution PDF
    null_pdf = norm.pdf(x, pop_mean, se)

    # Alternative distribution PDF (true mean)
    alt_pdf = norm.pdf(x, true_mean, se)

    plt.plot(x, null_pdf, label='Null Hypothesis', color='blue')
    plt.plot(x, alt_pdf, label='Alternative Hypothesis', color='green')

    # Shade Type 1 error region (alpha) under null
    x_alpha_right = np.linspace(upper_crit, pop_mean + 4*se, 100)
    x_alpha_left = np.linspace(pop_mean - 4*se, lower_crit, 100)
    plt.fill_between(x_alpha_right, 0, norm.pdf(x_alpha_right, pop_mean, se), color='red', alpha=0.3, label='Type 1 Error (α)')
    plt.fill_between(x_alpha_left, 0, norm.pdf(x_alpha_left, pop_mean, se), color='red', alpha=0.3)

    # Shade Type 2 error region (beta) under alternative
    beta_region = np.linspace(lower_crit, upper_crit, 100)
    plt.fill_between(beta_region, 0, norm.pdf(beta_region, true_mean, se), color='orange', alpha=0.3, label='Type 2 Error (β)')

    # Plot critical values
    plt.axvline(lower_crit, color='black', linestyle='--', label='Critical Values')
    plt.axvline(upper_crit, color='black', linestyle='--')

    plt.title('Type 1 and Type 2 Errors in Hypothesis Testing')
    plt.xlabel('Sample Mean')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True)
    plt.show()

# Example usage
plot_type1_type2_errors(
    pop_mean=50,        # Null hypothesis mean
    pop_std=10,         # Population std dev
    sample_size=30,
    alpha=0.05,         # Significance level
    true_mean=55        # Actual mean under alternative hypothesis
)

# %% [markdown]
# 6. Write a Python program to perform an independent T-test and interpret the results.

# %%
import numpy as np
from scipy.stats import ttest_ind

# Sample data for two independent groups
group1 = [12, 15, 14, 10, 13, 12, 11, 14, 13, 12]
group2 = [9, 8, 7, 10, 6, 9, 7, 5, 8, 6]

# Perform independent T-test (assumes unequal variances by default)
t_stat, p_value = ttest_ind(group1, group2, equal_var=False)

print(f"T-statistic: {t_stat:.3f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: the group means are significantly different.")
else:
    print("Fail to reject the null hypothesis: no significant difference between group means.")
# Out:
# T-statistic: 7.387
# P-value: 0.0000
# Reject the null hypothesis: the group means are significantly different.

# %% [markdown]
# 7. Perform a paired sample T-test using Python and visualize the comparison results.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_rel

# Sample paired data (e.g., measurements before and after treatment)
before = [85, 90, 88, 75, 95, 92, 89, 84, 91, 87]
after =  [88, 93, 90, 78, 97, 95, 91, 86, 94, 89]

# Perform paired T-test
t_stat, p_value = ttest_rel(before, after)

print(f"Paired T-test t-statistic: {t_stat:.3f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Reject null hypothesis: significant difference between paired samples.")
else:
    print("Fail to reject null hypothesis: no significant difference between paired samples.")

# Visualization
plt.figure(figsize=(8, 5))
plt.plot(before, 'o-', label='Before', color='blue')
plt.plot(after, 's-', label='After', color='orange')

for i in range(len(before)):
    plt.plot([i, i], [before[i], after[i]], 'k--', alpha=0.5)  # line connecting pairs

plt.xticks(range(len(before)))
plt.xlabel('Sample Index')
plt.ylabel('Measurement')
plt.title('Paired Sample Measurements Before and After')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Paired T-test t-statistic: -15.000
# P-value: 0.0000
# Reject null hypothesis: significant difference between paired samples.

# %% [markdown]
# 8. Simulate data and perform both Z-test and T-test, then compare the results using Python.

# %%
import numpy as np
from scipy.stats import norm, t

# Simulate data
np.random.seed(0)
sample_size = 30
pop_mean = 100
pop_std = 15  # population std dev (known)

# Generate sample data from normal distribution
sample = np.random.normal(loc=102, scale=pop_std, size=sample_size)

# Sample stats
sample_mean = np.mean(sample)
sample_std = np.std(sample, ddof=1)  # sample std dev

# Z-test (population std dev known)
z_stat = (sample_mean - pop_mean) / (pop_std / np.sqrt(sample_size))
z_p_value = 2 * (1 - norm.cdf(abs(z_stat)))

# T-test (population std dev unknown)
t_stat = (sample_mean - pop_mean) / (sample_std / np.sqrt(sample_size))
t_df = sample_size - 1
t_p_value = 2 * (1 - t.cdf(abs(t_stat), df=t_df))

print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-test: z = {z_stat:.3f}, p-value = {z_p_value:.4f}")
print(f"T-test: t = {t_stat:.3f}, p-value = {t_p_value:.4f}")

# Interpretation
alpha = 0.05
def interpret_test(p_val):
    return "Reject H0 (significant)" if p_val < alpha else "Fail to reject H0 (not significant)"

print("Z-test result:", interpret_test(z_p_value))
print("T-test result:", interpret_test(t_p_value))
# Out:
# Sample Mean: 108.64
# Z-test: z = 3.156, p-value = 0.0016
# T-test: t = 2.868, p-value = 0.0076
# Z-test result: Reject H0 (significant)
# T-test result: Reject H0 (significant)

# %% [markdown]
# 9. Write a Python function to calculate the confidence interval for a sample mean and explain its significance.

# %%
import numpy as np
from scipy.stats import t

def confidence_interval(data, confidence=0.95):
    n = len(data)
    mean = np.mean(data)
    std_err = np.std(data, ddof=1) / np.sqrt(n)

    # t critical value for two-tailed test
    t_crit = t.ppf((1 + confidence) / 2, df=n-1)

    margin_of_error = t_crit * std_err
    lower_bound = mean - margin_of_error
    upper_bound = mean + margin_of_error

    return (lower_bound, upper_bound)

# Example usage
sample_data = [12, 15, 14, 10, 13, 12, 11, 14, 13, 12]
ci_lower, ci_upper = confidence_interval(sample_data, confidence=0.95)

print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# 95% Confidence Interval: (11.52, 13.68)

# %% [markdown]
# 10. Write a Python program to calculate the margin of error for a given confidence level using sample data.

# %%
import numpy as np
from scipy.stats import t

def margin_of_error(data, confidence=0.95):
    n = len(data)
    std_err = np.std(data, ddof=1) / np.sqrt(n)  # standard error
    t_crit = t.ppf((1 + confidence) / 2, df=n-1)  # t critical value
    return t_crit * std_err

# Example usage
sample_data = [12, 15, 14, 10, 13, 12, 11, 14, 13, 12]
moe = margin_of_error(sample_data, confidence=0.95)
print(f"Margin of Error at 95% confidence: {moe:.3f}")
# Out:
# Margin of Error at 95% confidence: 1.077

# %% [markdown]
# 11.  Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process.

# %%
def bayes_theorem(prior, likelihood, false_positive_rate):
    """
    prior: P(Disease)
    likelihood: P(Pos | Disease)
    false_positive_rate: P(Pos | No Disease) = 1 - specificity
    """
    # P(No Disease)
    prior_neg = 1 - prior

    # Total probability of positive test: P(Pos)
    p_pos = likelihood * prior + false_positive_rate * prior_neg

    # Posterior: P(Disease | Pos)
    posterior = (likelihood * prior) / p_pos
    return posterior

# Given values
P_disease = 0.01
P_pos_given_disease = 0.95
P_pos_given_no_disease = 1 - 0.90  # 0.10 false positive rate

posterior_prob = bayes_theorem(P_disease, P_pos_given_disease, P_pos_given_no_disease)
print(f"Probability of disease given positive test: {posterior_prob:.4f}")
# Out:
# Probability of disease given positive test: 0.0876

# %% [markdown]
# 12.  Perform a Chi-square test for independence between two categorical variables in Python.

# %%
import numpy as np
from scipy.stats import chi2_contingency

# Example contingency table: rows = variable A categories, columns = variable B categories
# Suppose data counts of observations in each category combination
contingency_table = np.array([
    [30, 10, 20],
    [20, 20, 15],
    [10, 15, 25]
])

# Perform Chi-square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

print(f"Chi-square statistic: {chi2:.3f}")
print(f"P-value: {p:.4f}")
print(f"Degrees of freedom: {dof}")
print("Expected frequencies:")
print(expected)

# Interpretation
alpha = 0.05
if p < alpha:
    print("Reject null hypothesis: variables are dependent (association exists).")
else:
    print("Fail to reject null hypothesis: variables are independent.")
# Out:
# Chi-square statistic: 14.986
# P-value: 0.0047
# Degrees of freedom: 4
# Expected frequencies:
# [[21.81818182 16.36363636 21.81818182]
#  [20.         15.         20.        ]
#  [18.18181818 13.63636364 18.18181818]]
# Reject null hypothesis: variables are dependent (association exists).

# %% [markdown]
# 13. Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data

# %%
import numpy as np

def expected_frequencies(observed):
    # Row sums and column sums
    row_sums = observed.sum(axis=1).reshape(-1, 1)
    col_sums = observed.sum(axis=0).reshape(1, -1)
    total = observed.sum()

    # Expected frequency = (row_sum * col_sum) / total
    expected = (row_sums @ col_sums) / total
    return expected

# Example observed data
observed_data = np.array([
    [30, 10, 20],
    [20, 20, 15],
    [10, 15, 25]
])

expected = expected_frequencies(observed_data)
print("Observed Frequencies:")
print(observed_data)
print("\nExpected Frequencies:")
print(expected)
# Out:
# Observed Frequencies:
# [[30 10 20]
#  [20 20 15]
#  [10 15 25]]
#
# Expected Frequencies:
# [[21.81818182 16.36363636 21.81818182]
#  [20.         15.         20.        ]
#  [18.18181818 13.63636364 18.18181818]]

# %% [markdown]
# 14. Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.

# %%
import numpy as np
from scipy.stats import chisquare

# Observed frequencies (e.g., counts in categories)
observed = np.array([50, 30, 20])

# Expected frequencies (must sum to same total as observed)
expected = np.array([40, 40, 20])

# Perform Chi-square goodness-of-fit test
chi2_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

print(f"Chi-square statistic: {chi2_stat:.3f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Reject null hypothesis: observed distribution differs from expected.")
else:
    print("Fail to reject null hypothesis: observed distribution matches expected.")
# Out:
# Chi-square statistic: 5.000
# P-value: 0.0821
# Fail to reject null hypothesis: observed distribution matches expected.
